# %%
# %sql
CREATE OR REPLACE TABLE vstone.gold.airport_delay_summary_security_demo AS
SELECT *
FROM vstone.gold.airport_delay_summary;

# %%
# %sql
select * from vstone.gold.airport_delay_summary_security_demo

# %%
# %sql
select * from vstone.gold.airport_delay_summary
