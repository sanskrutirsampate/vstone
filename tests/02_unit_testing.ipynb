# %%
# %sql
show tables in  vstone.bronze;

# %%
# %sql
select count(*) from vstone.bronze.flight_json_bronze;

# %%
# %sql
select * from vstone.bronze.flight_json_bronze 
limit10;

# %%
# %sql
describe table vstone.bronze.flight_json_bronze;

# %%
# %sql
describe history vstone.bronze.flight_json_bronze;
