# %%
# %sql
select count(*) from vstone.bronze.flight_xml_bronze;

# %%
# %sql
select * from vstone.bronze.flight_xml_bronze
limit 10;

# %%
# %sql
describe table vstone.bronze.flight_xml_bronze;

# %%
# %sql
describe history vstone.bronze.flight_xml_bronze;
