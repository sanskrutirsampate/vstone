# %%
# %sql
select count(*) from vstone.bronze.flight_csv_incremental_bronze;

# %%
# %sql
select * from vstone.bronze.flight_csv_incremental_bronze
limit 10;

# %%
# %sql
describe  table vstone.bronze.flight_csv_incremental_bronze;

# %%
# %sql
show tables in vstone.bronze;
