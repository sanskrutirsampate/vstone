# %%
# %sql
SELECT COUNT(*)
FROM vstone.gold.staging_flights;

# %%
# %sql
SELECT COUNT(*)
FROM vstone.gold.dim_airline;

# %%
# %sql
SELECT COUNT(*)
FROM vstone.gold.dim_airport;

# %%
# %sql
SELECT COUNT(*)
FROM vstone.gold.fact_flight_delays;

# %%
# %sql
SELECT *
FROM vstone.gold.airline_delay_summary;

# %%
# %sql
SELECT *
FROM vstone.gold.airport_delay_summary;

# %%
# %sql
SELECT *
FROM vstone.gold.monthly_delay_summary;

# %%
# %sql
SELECT *
FROM vstone.gold.route_delay_summary;

# %%
# %sql
SELECT *
FROM vstone.gold.cancellation_summary;

# %%
# %sql
SELECT COUNT(*)
FROM vstone.gold.fact_flight_delays
WHERE airline_sk IS NULL;

# %%
# %sql
SELECT load_dt,
source
FROM vstone.gold.fact_flight_delays
LIMIT 10;

# %%
# %sql
SELECT COUNT(DISTINCT airline_sk)
FROM vstone.gold.dim_airline;
